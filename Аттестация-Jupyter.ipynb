# %% [markdown]
# #   Задача 1.
# ### Постройте график. Назовите график. Сделайте наименование оси x и оси y. Сделайте выводы

# %% [markdown]
# ### 1.1 Скачайте следющие данные: kc_house_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv', encoding = 'windows-1251')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['price'],bins=20)
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Цена')
plt.ylabel('Количество');

# %% [markdown]
# #### *Вывод: наибольшее количество недвижимости с меньшей стоимостью*

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой площади

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['sqft_living'], bins=20)
plt.title('Распределение квадратуры жилой площади')
plt.xlabel('Жилые кв. метры')
plt.ylabel('Количество');

# %% [markdown]
# #### *Вывод: жилой площади более 2000 кв.метров*

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(8, 10))
plt.hist(df['yr_built'], bins=25)
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество');

# %% [markdown]
# #### *Вывод: наименьшее количество домов было построено в период с 1900 по 1940 годы. Пик строительства приходится на двухтыесячные годы*

# %% [markdown]
# # Задача 2.

# %% [markdown]
# ### 2.1. Изучите распределение домов от наличия вида на набережную. Постройте график. Сделайте выводы

# %%
df.head(1)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
#
#    sqft_lot15
# 0        5650
#
# [1 rows x 21 columns]

# %%
data = df['waterfront'].value_counts()
data
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 8))
plt.pie(data, labels=data.index, autopct='%1.2f%%')
plt.legend(['no', 'yes'])
plt.title('Распределение домов с видом на набережную')
# Out:
# Text(0.5, 1.0, 'Распределение домов с видом на набережную')

# %% [markdown]
# #### *Вывод: домов с видом на набережную всего 0,75 процента от общего количества*

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
data
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 8))
plt.pie(data, labels=data.index, autopct='%1.2f%%')
plt.title('Распределение количества этажей');

# %% [markdown]
# #### *Вывод: большинство домов одноэтоажные. На втором месте, в большом количестве, двухэтажные дома. Наименьшее количество домов с этажностью 3,5*

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
data = df['condition'].value_counts()
data
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
plt.bar(data.index, np.log(data))
plt.xticks(rotation=50)
plt.xlabel('Оценка')
plt.ylabel('Количество')
plt.title('Состояние домов');

# %% [markdown]
# #### *Вывод: большинство домов в удовлетворительном и хорошем состоянии. Домов в плохом и неудовлетворительном состоянии менее одного процента*

# %% [markdown]
# # Задача 3
# ### Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
df.sample()
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 5338  2215901310  20141114T000000  303500.0         4        2.5         1920
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 5338      7345     2.0           0     0  ...      8        1920
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 5338              0      1992             0    98038  47.3526 -122.055
#
#       sqft_living15  sqft_lot15
# 5338           1860        7364
#
# [1 rows x 21 columns]

# %%
sns.scatterplot(data=df, x='price', y='view')
plt.title('Вид из окна');

# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

plt.figure(figsize=(10, 6)) 
sns.lineplot(data=df, x='view', y='price')
plt.xlabel('Оценка вида')
plt.ylabel('Цена')
plt.title('Влияние вида из окна на цену') 

plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### *Вывод: чем красивее вид из окна, тем дороже стоимость жилья*

# %%
sns.scatterplot(data=df, x='bedrooms', y='price', hue='sqft_living')
plt.xlabel('Колчиество спален')
plt.ylabel('Цена')
plt.title('Влияние количества спален на стоимость');

# %% [markdown]
# #### *Вывод: самые дорогие квартиры с пятью спльнями и большой площадью*

# %%
df.sample()
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 5955  2473400290  20150126T000000  285000.0         4        2.5         1870
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 5955      8190     1.0           0     0  ...      7        1100
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 5955            770      1977             0    98058  47.4521 -122.161
#
#       sqft_living15  sqft_lot15
# 5955           1590        9150
#
# [1 rows x 21 columns]

# %%
sns.boxplot(x=df['price'], y=df['floors'].astype('str'), whis=1.5);
plt.xlabel('Цена')
plt.ylabel('Количество этажей')
plt.title('Влияние количества этажей на стоимость');

# %% [markdown]
# #### *Вывод: самые дорогие дома имеют этажность 2,5*

# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
 
    plt.figure(figsize=(15,8)) 
    ax = sns.lineplot(x='yr_built', y='price', data=df, marker='o')
    years = np.arange(df['yr_built'].min(), df['yr_built'].max()+1, 5) 
    ax.set_xticks(years)
    ax.set_xlabel('Год постройки')
    ax.set_ylabel('Стоимость')
    ax.set_title('Влияние года постройки на стоимость здания')

plt.show()

# %% [markdown]
# #### *Вывод: дороже оцениваются дома построенные в период с 1905 по 1910, с 1930 по 1935, с 2000 по 2005, а так же в 2015 годах*

# %%
corr_m=df[['bedrooms', 'view', 'floors', 'yr_built', 'waterfront', 'sqft_lot', 'price']].corr().round(2)
corr_m
# Out:
#             bedrooms  view  floors  yr_built  waterfront  sqft_lot  price
# bedrooms        1.00  0.08    0.18      0.15       -0.01      0.03   0.31
# view            0.08  1.00    0.03     -0.05        0.40      0.07   0.40
# floors          0.18  0.03    1.00      0.49        0.02     -0.01   0.26
# yr_built        0.15 -0.05    0.49      1.00       -0.03      0.05   0.05
# waterfront     -0.01  0.40    0.02     -0.03        1.00      0.02   0.27
# sqft_lot        0.03  0.07   -0.01      0.05        0.02      1.00   0.09
# price           0.31  0.40    0.26      0.05        0.27      0.09   1.00

# %%
sns.heatmap(corr_m, annot=True, cmap='coolwarm', linewidths=1)
plt.title('Матрица корреляций');

# %% [markdown]
# #### *Вывод: если вы захотите приобрести домик на побережье с прекрасным видом из окна, в котором будет большое количество спален и два этажа с мансардой, то вам необходимо учитывать, что это будет смое дорогое по стоимости жилье и нужно располагать большой суммой дененг для этой покупки. При этом площадь участка и год постройки будут иметь не самое большое значение*
